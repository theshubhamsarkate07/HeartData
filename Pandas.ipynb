# %% [markdown]
# # Pandas

# %%
1. DataFrame - 2-D (rows and columns)
2. Series - 1D (single column)

# %%
# Create Dataframe
1. list
2. numpy array
3. tuple
4. dict
5. series
6. csv file
7. excel 
8. json

# %%
1. pd.DataFrame()
2. pd.Series()
3. df.shape # rows and columns
4. df.columns
5. df.index
6. df.axes
7. df.dtypes
8. df.info
9. df.describe
10. df.head()
12. df.tail()
13. Access Columns
    1. df[col_name]
    2. df[col_names_list]
    
14. df.iloc[row_index, column_index]
15. df.loc[row_labels, column_labels]

16. pd.read_csv()
17. pd.read_excel()

# %%
import pandas as pd 
import numpy as np

# %%
emp_df = pd.read_csv('Emp_Records.csv')
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   100 non-null    int64
#  4   Age in Company  100 non-null    float64
#  5   Salary          100 non-null    int64
#  6   City            100 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 5.6+ KB

# %%
emp_df.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000     100.000000      100.000000     100.000000
# mean   547652.10000   39.238700      58.080000        8.978400  119738.090000
# std    257664.16679   12.066252      12.294106        8.657358   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.152500   83979.750000
# 50%    497414.00000   37.595000      56.000000        6.435000  118049.500000
# 75%    766040.00000   49.900000      61.250000       13.762500  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
emp_df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
emp_df.tail()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %% [markdown]
# # Access Rows and Columns

# %%
1. slicing method

# %%
emp_df[2:5] # 2,3,4
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
2. iloc >> df.iloc[row_index, col_index]

# %%
emp_df.iloc[:, :]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.iloc[10:21, 2:6]   # rows 10 to 20, col 2 to 5
# Out:
#     Age in Yrs  Weight in Kgs  Age in Company  Salary
# 10       42.50             80            8.29  118457
# 11       22.21             61            0.56   82965
# 12       45.45             55            1.68  166892
# 13       21.10             87            0.02   92758
# 14       59.47             47           26.69   92220
# 15       50.97             42           22.95  152654
# 16       47.23             68           14.91  184896
# 17       24.66             59            2.52  197537
# 18       58.08             56           12.43  141518
# 19       49.85             73           19.15   73862
# 20       22.64             56            1.26   93967

# %%
emp_df.iloc[[2,4,5], 2:]
# Out:
#    Age in Yrs  Weight in Kgs  Age in Company  Salary          City
# 2       54.15             68            0.98   50155  Michigantown
# 4       40.31             58            4.01  117642       Fremont
# 5       34.86             58           12.02   72305     Macksburg

# %% [markdown]
# # 3.loc

# %%
emp_df.loc[: , :]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.loc[0:3 , :]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown

# %%
emp_df.iloc[0:4, :]   # index
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown

# %%
emp_df.loc[0:3 ,'Age in Yrs']
# Out:
# 0    36.36
# 1    47.02
# 2    54.15
# 3    39.67
# Name: Age in Yrs, dtype: float64

# %%
emp_df.loc[0:3 ,'Age in Yrs' : 'City']
# Out:
#    Age in Yrs  Weight in Kgs  Age in Company  Salary          City
# 0       36.36             60           13.68  168251        Denver
# 1       47.02             60            9.01   51063     Stonewall
# 2       54.15             68            0.98   50155  Michigantown
# 3       39.67             51           18.30  180294      Hydetown

# %%
emp_df.loc[0:3 ,['Age in Yrs' , 'Salary', 'City']]
# Out:
#    Age in Yrs  Salary          City
# 0       36.36  168251        Denver
# 1       47.02   51063     Stonewall
# 2       54.15   50155  Michigantown
# 3       39.67  180294      Hydetown

# %%
emp_df.loc[[2,4,7,8] ,['Age in Yrs' , 'Salary', 'City']]
# Out:
#    Age in Yrs  Salary          City
# 2       54.15   50155  Michigantown
# 4       40.31  117642       Fremont
# 7       59.12   60918   Blanchester
# 8       58.18  121587       Delmita

# %%
df_test = pd.DataFrame(np.random.randint(20,30, size = (7,5)), index =
                       list('abcdefg'), columns = list('KLMNO'))
df_test
# Out:
#     K   L   M   N   O
# a  20  21  23  24  27
# b  20  21  20  24  29
# c  25  24  23  26  28
# d  22  29  26  24  28
# e  20  29  25  25  21
# f  28  25  27  29  24
# g  27  28  24  24  20

# %%
df_test.loc['c' : 'e', :]
# Out:
#     K   L   M   N   O
# c  25  24  23  26  28
# d  22  29  26  24  28
# e  20  29  25  25  21

# %%
df_test.loc['c' : 'e', ['K', 'N']]
# Out:
#     K   N
# c  25  26
# d  22  24
# e  20  25

# %%
df_test.loc[['a','e'], ['K', 'N']]
# Out:
#     K   N
# a  20  24
# e  20  25

# %%
df_test['P'] = np.arange(10,17)
df_test
# Out:
#     K   L   M   N   O   P
# a  20  21  23  24  27  10
# b  20  21  20  24  29  11
# c  25  24  23  26  28  12
# d  22  29  26  24  28  13
# e  20  29  25  25  21  14
# f  28  25  27  29  24  15
# g  27  28  24  24  20  16

# %%
df_test['Q'] = np.arange(10,15)
df_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SUCHIT~1.BER\AppData\Local\Temp/ipykernel_18100/306898531.py in <module>
# ----> 1 df_test['Q'] = np.arange(10,15)
#       2 df_test
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
# ...

# %%
df_test
# Out:
#     K   L   M   N   O   P
# a  20  21  23  24  27  10
# b  20  21  20  24  29  11
# c  25  24  23  26  28  12
# d  22  29  26  24  28  13
# e  20  29  25  25  21  14
# f  28  25  27  29  24  15
# g  27  28  24  24  20  16

# %%
df_test.iloc[2,3]
# Out:
# 26

# %%
df_test.iloc[2,3]  = 1000
df_test
# Out:
#     K   L   M     N   O   P
# a  20  21  23    24  27  10
# b  20  21  20    24  29  11
# c  25  24  23  1000  28  12
# d  22  29  26    24  28  13
# e  20  29  25    25  21  14
# f  28  25  27    29  24  15
# g  27  28  24    24  20  16

# %%
df_test.iloc[2,3]  = np.nan   # To replace any value with null value
df_test
# Out:
#     K   L   M     N   O   P
# a  20  21  23  24.0  27  10
# b  20  21  20  24.0  29  11
# c  25  24  23   NaN  28  12
# d  22  29  26  24.0  28  13
# e  20  29  25  25.0  21  14
# f  28  25  27  29.0  24  15
# g  27  28  24  24.0  20  16

# %%
df_test.to_csv('Data_test.csv')

# %%
df_test.loc['d', 'M']  = np.nan 
df_test
# Out:
#       K     L     M     N     O     P
# a  20.0  21.0  23.0  24.0  27.0  10.0
# b  20.0  21.0  20.0  24.0  29.0  11.0
# c  25.0  24.0  23.0   NaN  28.0  12.0
# d  22.0  29.0   NaN  24.0  28.0  13.0
# e  20.0  29.0  25.0  25.0  21.0  14.0
# f  28.0  25.0  27.0  29.0  24.0  15.0
# g  27.0  28.0  24.0  24.0  20.0  16.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# # Detect missin values

# %%
df = pd.read_csv('Emp_Records.csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.iloc[2,3]  = np.nan   # To replace any value with null value
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15            NaN            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False           True           False   False
# 3    False       False       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     1
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
df.isnull()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False           True           False   False
# 3    False       False       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isnull().sum() # To get num of null values for each column
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     1
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# Emp ID            0.0
# First Name        0.0
# Age in Yrs        0.0
# Weight in Kgs     1.0
# Age in Company    0.0
# Salary            0.0
# City              0.0
# dtype: float64

# %%
emp_df = pd.read_csv('Emp_Records_Test.csv')
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df.isna().sum()
# Out:
# Emp ID             0
# First Name         1
# Age in Yrs        10
# Weight in Kgs      9
# Age in Company     5
# Salary             3
# City               1
# dtype: int64

# %%
emp_df.isnull().sum()
# Out:
# Emp ID             0
# First Name         1
# Age in Yrs        10
# Weight in Kgs      9
# Age in Company     5
# Salary             3
# City               1
# dtype: int64

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      99 non-null     object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   91 non-null     float64
#  4   Age in Company  95 non-null     float64
#  5   Salary          97 non-null     float64
#  6   City            99 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.6+ KB

# %% [markdown]
# # 2. Fill mising values

# %%
1. mean()
2. median()
3. mode()
4. min()
5. max()
6. static value >> 1000
 static value >> -99999

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
type(emp_df['Age in Yrs'])
# Out:
# pandas.core.series.Series

# %%
emp_df['Age in Yrs'].mean()
# Out:
# 38.49133333333334

# %%
emp_df['Age in Yrs'].median()
# Out:
# 36.815

# %%
emp_df['Age in Yrs'].mode()[0]
# Out:
# 21.1

# %%
emp_df['Age in Yrs'].min()
# Out:
# 21.1

# %%
emp_df['Age in Yrs'].max()
# Out:
# 59.47

# %%
array = np.random.randint(10,30, size = 7)
array
# Out:
# array([24, 14, 17, 23, 24, 12, 21])

# %%
np.mean(array)
# Out:
# 19.285714285714285

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df.fillna(1000)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0         1000.00  168251.0
# 1   940761     Brenda     1000.00         1000.0            9.01   51063.0
# 2   428945        Joe     1000.00           68.0         1000.00   50155.0
# 3   408351      Diane     1000.00         1000.0         1000.00    1000.0
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df.fillna(100)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0          100.00  168251.0
# 1   940761     Brenda      100.00          100.0            9.01   51063.0
# 2   428945        Joe      100.00           68.0          100.00   50155.0
# 3   408351      Diane      100.00          100.0          100.00     100.0
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df['Age in Yrs'] = emp_df['Age in Yrs'].fillna(100)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda      100.00            NaN            9.01   51063.0
# 2   428945        Joe      100.00           68.0             NaN   50155.0
# 3   408351      Diane      100.00            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df['Weight in Kgs'].fillna(2000, inplace =  True)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda      100.00         2000.0            9.01   51063.0
# 2   428945        Joe      100.00           68.0             NaN   50155.0
# 3   408351      Diane      100.00         2000.0             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df['Age in Company'].fillna(0)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda      100.00         2000.0            9.01   51063.0
# 2   428945        Joe      100.00           68.0             NaN   50155.0
# 3   408351      Diane      100.00         2000.0             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df['Age in Company'].mean()
# Out:
# 8.731473684210526

# %%
emp_df['Age in Company'].fillna(8.731473684210526, inplace = True)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0        8.731474  168251.0
# 1   940761     Brenda      100.00         2000.0        9.010000   51063.0
# 2   428945        Joe      100.00           68.0        8.731474   50155.0
# 3   408351      Diane      100.00         2000.0        8.731474       NaN
# 4   193819   Benjamin       40.31           58.0        4.010000  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0        1.050000  129774.0
# 96  704709     Harold       32.61           77.0        5.930000  156194.0
# 97  461593     Nicole       52.66           60.0       28.530000   95673.0
# 98  392491    Theresa       29.60           57.0        6.990000   51015.0
# 99  495141      Tammy       38.38           55.0        2.260000   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0        8.731474  168251.0
# 1   940761     Brenda      100.00         2000.0        9.010000   51063.0
# 2   428945        Joe      100.00           68.0        8.731474   50155.0
# 3   408351      Diane      100.00         2000.0        8.731474       NaN
# 4   193819   Benjamin       40.31           58.0        4.010000  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0        1.050000  129774.0
# 96  704709     Harold       32.61           77.0        5.930000  156194.0
# 97  461593     Nicole       52.66           60.0       28.530000   95673.0
# 98  392491    Theresa       29.60           57.0        6.990000   51015.0
# 99  495141      Tammy       38.38           55.0        2.260000   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df['Salary'].mean()
# Out:
# 119942.35051546391

# %%
emp_df['Salary'].fillna(emp_df['Salary'].mean(), inplace = True)
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  \
# 0   677509       Lois       36.36           60.0        8.731474
# 1   940761     Brenda      100.00         2000.0        9.010000
# 2   428945        Joe      100.00           68.0        8.731474
# 3   408351      Diane      100.00         2000.0        8.731474
# 4   193819   Benjamin       40.31           58.0        4.010000
# ..     ...        ...         ...            ...             ...
# 95  639892       Jose       22.82           89.0        1.050000
# 96  704709     Harold       32.61           77.0        5.930000
# 97  461593     Nicole       52.66           60.0       28.530000
# 98  392491    Theresa       29.60           57.0        6.990000
# 99  495141      Tammy       38.38           55.0        2.260000
#
#            Salary          City
# 0   168251.000000        Denver
# 1    51063.000000     Stonewall
# 2    50155.000000  Michigantown
# 3   119942.350515      Hydetown
# ...

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].fillna(df['Age'].min(), inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean >> no outliers
median >> median outliers
mode >> categorial variable

# %%
df['Gender'].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
from scipy import stats

# %%
stats.mode(df['Gender'])[0][0]
# Out:
# 'male'

# %%
[1,2,3,5,6,7,100000, 8,9,10, 9999999] # outliers 100000, 9999999

Age >> [25,34,45,32,50,44,46, 100, 1000] # outliers 100, 1000

# %%
age = np.array([25,34,45,32,50,44,46, 100, 1000])
np.mean(age)
# Out:
# 152.88888888888889

# %%
age = np.array([25,34,45,32,50,44,46])
np.mean(age)
# Out:
# 39.42857142857143

# %%
age = np.array([25,34,45,32,50,44,46, 100, 1000])
np.median(age)
# Out:
# 45.0

# %%
age = np.array([1, 0.2, 25,34,45,32,50,44,46, 100, 1000])
np.median(age)
# Out:
# 44.0

# %% [markdown]
# # 3. dropna

# %%
emp_df = pd.read_csv('Emp_Records_Test.csv')
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
emp_df.isnull().sum()
# Out:
# Emp ID             0
# First Name         1
# Age in Yrs        10
# Weight in Kgs      9
# Age in Company     5
# Salary             3
# City               1
# dtype: int64

# %% [markdown]
# # drop rows

# %%
emp_df.dropna(inplace = False)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# 8   477616    Frances       58.18           42.0           23.27  121587.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50           80.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#               City
# 4          Fremont
# 8          Delmita
# ...

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 3   408351      Diane         NaN            NaN             NaN       NaN
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %%
  Emp ID	First Name	 Age in Yrs	  Weight in Kgs	 Age in Company	  Salary	  City
1 940761	Brenda	     NaN	      NaN	     9.01	          51063.0	  Stonewall # 5 non-null
4 193819	Benjamin	 40.31	      58.0	     4.01	          117642.0	  Fremont   # 7 non-null

# %%
emp_df.dropna(thresh = 7) # 7 non - null
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# 8   477616    Frances       58.18           42.0           23.27  121587.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50           80.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#               City
# 4          Fremont
# 8          Delmita
# ...

# %%
emp_df.dropna(thresh = 5) # 5 non - null
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0             NaN  168251.0
# 1   940761     Brenda         NaN            NaN            9.01   51063.0
# 2   428945        Joe         NaN           68.0             NaN   50155.0
# 4   193819   Benjamin       40.31           58.0            4.01  117642.0
# 5   499687    Patrick       34.86            NaN           12.02   72305.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# ...

# %% [markdown]
# ## drop columns

# %%
emp_df = pd.read_csv('Emp_Records_Test.csv')
emp_df = emp_df.head(10)
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0  677509       Lois       36.36           60.0             NaN  168251.0
# 1  940761     Brenda         NaN            NaN            9.01   51063.0
# 2  428945        Joe         NaN           68.0             NaN   50155.0
# 3  408351      Diane         NaN            NaN             NaN       NaN
# 4  193819   Benjamin       40.31           58.0            4.01  117642.0
# 5  499687    Patrick       34.86            NaN           12.02   72305.0
# 6  539712      Nancy       22.14           50.0             NaN       NaN
# 7  380086        NaN         NaN            NaN             NaN       NaN
# 8  477616    Frances       58.18           42.0           23.27  121587.0
# 9  162402      Diana       29.73           60.0            3.44   43010.0
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# ...

# %%
emp_df.dropna(axis = 1) # to drop the column having null values
# Out:
#    Emp ID
# 0  677509
# 1  940761
# 2  428945
# 3  408351
# 4  193819
# 5  499687
# 6  539712
# 7  380086
# 8  477616
# 9  162402

# %%
emp_df.dropna(thresh = 6, axis = 1)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs    Salary            City
# 0  677509       Lois       36.36           60.0  168251.0          Denver
# 1  940761     Brenda         NaN            NaN   51063.0       Stonewall
# 2  428945        Joe         NaN           68.0   50155.0    Michigantown
# 3  408351      Diane         NaN            NaN       NaN        Hydetown
# 4  193819   Benjamin       40.31           58.0  117642.0         Fremont
# 5  499687    Patrick       34.86            NaN   72305.0       Macksburg
# 6  539712      Nancy       22.14           50.0       NaN         Atlanta
# 7  380086        NaN         NaN            NaN       NaN             NaN
# 8  477616    Frances       58.18           42.0  121587.0         Delmita
# 9  162402      Diana       29.73           60.0   43010.0  Eureka Springs

# %% [markdown]
# # Drop

# %%
emp_df
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0  677509       Lois       36.36           60.0             NaN  168251.0
# 1  940761     Brenda         NaN            NaN            9.01   51063.0
# 2  428945        Joe         NaN           68.0             NaN   50155.0
# 3  408351      Diane         NaN            NaN             NaN       NaN
# 4  193819   Benjamin       40.31           58.0            4.01  117642.0
# 5  499687    Patrick       34.86            NaN           12.02   72305.0
# 6  539712      Nancy       22.14           50.0             NaN       NaN
# 7  380086        NaN         NaN            NaN             NaN       NaN
# 8  477616    Frances       58.18           42.0           23.27  121587.0
# 9  162402      Diana       29.73           60.0            3.44   43010.0
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# ...

# %%
emp_df.drop(['Emp ID', 'City'], axis = 1, inplace = True)
emp_df
# Out:
#   First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary
# 0       Lois       36.36           60.0             NaN  168251.0
# 1     Brenda         NaN            NaN            9.01   51063.0
# 2        Joe         NaN           68.0             NaN   50155.0
# 3      Diane         NaN            NaN             NaN       NaN
# 4   Benjamin       40.31           58.0            4.01  117642.0
# 5    Patrick       34.86            NaN           12.02   72305.0
# 6      Nancy       22.14           50.0             NaN       NaN
# 7        NaN         NaN            NaN             NaN       NaN
# 8    Frances       58.18           42.0           23.27  121587.0
# 9      Diana       29.73           60.0            3.44   43010.0

# %%
titanic_df = pd.read_csv('titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Features >> age, bmi(height,weight), diseases, sum insured, term
# Target >> Predict the premium

# %%
x = titanic_df.drop('Pclass', axis = 1)  # Features
y = titanic_df['Pclass']  #Target

# %%
x
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
y
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
titanic_df.drop([1,2,3])  # rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
5 // 2
# Out:
# 2
